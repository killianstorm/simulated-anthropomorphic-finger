# %% [markdown]
# <a href="https://colab.research.google.com/github/killianstorm/simulated-anthropomorphic-finger/blob/master/finger_model/notebooks/comparison_physical_setup/comparison_physical_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook will run the comparison between the physical setup and the simulator as described in the book at Chapter 5.
#
# For each of the comparisons, the graphs will be generated and displayed inside this notebook. The animations are saved in the folder with a timestamp at: /content/simulated-anthropomorphic-finger/finger_model/analysis/comparison

# %%
import sys
import os
sys.path.append('/content/simulated-anthropomorphic-finger/finger_model')
from analysis.comparison.comparison import *

location = "/content/simulated-anthropomorphic-finger/finger_model/analysis/comparison"
os.chdir(location)

# %% [markdown]
# The full grasp trajectory:

# %%
# Full grasp.
compare_sim_to_phys("grasp", "full grasp")
# Out:
# 100%|██████████| 167/167 [01:01<00:00,  2.73it/s]
# [MoviePy] Building file comparison_grasp_12-Jun-2020_(16:36:31.020546).gif with imageio
# 100%|██████████| 167/167 [01:10<00:00,  2.36it/s]
# The animation is called: comparison_grasp_12-Jun-2020_(16:36:31.020546)

# %% [markdown]
# The extended PIP trajectory:

# %%
# Extended PIP.
compare_sim_to_phys("0PIP", "extended PIP")

# %% [markdown]
# The extended MCP trajectory:

# %%
# Extended MCP.
compare_sim_to_phys("0MCP", "extended MCP")
# Out:
# Cloning into 'simulated-anthropomorphic-finger'...
# remote: Enumerating objects: 869, done.
# remote: Counting objects: 100% (869/869), done.
# remote: Compressing objects: 100% (549/549), done.
# remote: Total 869 (delta 464), reused 692 (delta 292), pack-reused 0
# Receiving objects: 100% (869/869), 48.69 MiB | 31.02 MiB/s, done.
# Resolving deltas: 100% (464/464), done.

# %% [markdown]
# The complex trajectory:

# %%
# Complex.
compare_sim_to_phys("complex", "complex trajectory")
