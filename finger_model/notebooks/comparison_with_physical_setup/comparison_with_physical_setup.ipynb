# %% [markdown]
# ### Comparison between the physical setup and the simulator for all trajectories.
# #### Animations are and graphs automatically generated with the provided name. The animations are saved in the workspace and not shown in this notebook. To view the animations, open them from the file explorer or visit:

# %%
import sys
import os
sys.path.insert(1, os.path.join(sys.path[0], '../../'))

from analysis.comparison.comparison import *

os.chdir("../../analysis/comparison")
# Out:
# /Users/kstorm/PycharmProjects/thesis/venv/lib/python3.7/site-packages/jax/lib/xla_bridge.py:116: UserWarning: No GPU/TPU found, falling back to CPU.
#   warnings.warn('No GPU/TPU found, falling back to CPU.')

# %%
# Full grasp.
compare_sim_to_phys("grasp", "full grasp")
# Out:
# ...
# t:   0%|          | 0/167 [00:00<?, ?it/s, now=None]
# MoviePy - Building file comparison_grasp_12-Jun-2020_(18:20:46.843939).gif with imageio.
# The animation is called: comparison_grasp_12-Jun-2020_(18:20:46.843939)

# %%
# Isometric PIP.
compare_sim_to_phys("0PIP", "extended PIP")

# %%
# Isometric MCP.
compare_sim_to_phys("0MCP", "extended MCP")

# %%
# Complex.
compare_sim_to_phys("0MCP", "extended MCP")
